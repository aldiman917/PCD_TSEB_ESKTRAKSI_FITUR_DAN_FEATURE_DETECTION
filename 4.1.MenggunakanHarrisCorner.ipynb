# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# Menggunakan gambar "kucing.jpg"
img = cv2.imread('kucing.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Menggunakan metode Harris Corner Detector
dst = cv2.cornerHarris(gray, 2, 3, 0.04)

# Membuat tanda pada titik pojok yang terdeteksi
dst = cv2.dilate(dst, None)
img[dst > 0.01 * dst.max()] = [0, 0, 255]  # Menandai pojok dengan warna merah

# menampilkan jumlah titik terdeteksi dengan fungsi numpy (np.ndarray.shape)
print("jumlah titik terdeteksi = ", corners.shape[0])

# Tampilkan gambar dengan pojok yang terdeteksi
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# jumlah titik terdeteksi =  277
